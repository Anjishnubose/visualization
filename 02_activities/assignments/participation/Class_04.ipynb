# %% [markdown]
# # Activity 1
# - I know it is the same data but the difference in size of (a) vs (b) is clearer in the bar plot, than in the circular plot. I guess this is because our brains are better at comparing 1d sizes than 2d areas.

# %% [markdown]
# # Activity 2
#
# ## Visualization 1
# - I will be very honest, this plot is not at all clear to me. If they had not marked the data explicitly with gun killings, I would be totally lost.
# - The data is not objective in the sense that the visualization clearly wants you to feel the loss in life rather than treat it as a logistical data point
#
# ## Visualization 2
# - This is a much more clear data visualization with data labelling. The plot shows incidents of gun violence over time in the US.
# - The data visualization is more ``objective", but clearly has the same interpretation.
