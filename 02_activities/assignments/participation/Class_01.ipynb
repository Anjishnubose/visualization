# %% [markdown]
# # Activity
#
# ## Visualization 1
# - The visualization is not very pleasing to look at. The color scheme is conflicting with the background chosen.
# - The data representation is unclear because of the weird 3d axis orientation
# - While the message may be understood as the difference in life expectancy in different continents, the axis is so weird that the differences is not clear.
#
# ## Visualization 2
# - The visualization is provocative and immideately puts across its point.
# - While the color scheme is fine, the axis distortion still manages to make the exact scale not very clear.
# - The message is very clear though : the balooning cost campaign expenditure.
#
# ## Visualization 3
# - Both the plots are very clear.
# - The data representation is also clear. Honestly, I do not see the difference in the aspect ratio changing the interpretation of the plots.
#
# ## Visualization 4
# - The plot is immediately confusing. How does a pie chart add up to more than 100%?
# - Choosing to plot a section of the pie chart in blue on a blue background is aesthetically weird.
# - The data just does not make sense in the plot.
#
# ## Visualization 5
# - The data visualization is quite nice. It very effectively shows wind speeds ovdrlayed on an actual geographical map.
# - The data representation is pretty clear with a colorscale used to represent the wind speed.
# - The plot clearly shows high wind speeds in the northern part of the US.
